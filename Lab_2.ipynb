# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahRazzaq-FASTian/AI-Lab-Tasks/blob/main/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Notification:
  def sendMessage(self):
    print("Sending generic notification...")

class EmailNotification(Notification):
  def sendMessage(self):
    print("Sending Email to user@example.com")

class SMSNotification(Notification):
  def sendMessage(self):
    print("Sending SMS to +923001234567")

EN = EmailNotification()
EN.sendMessage()

SN = SMSNotification()
SN.sendMessage()
# Out:
# Sending Email to user@example.com
# Sending SMS to +923001234567

# %%
class StudentGrades:
  def __init__(self, name, marks):
    self.student_name = name
    self.__marks = marks
  def getMarks(self):
    return self.__marks
  def addMarks(self, marks):
    if(marks < 0 or marks > 100):
      print("Invalid marks")
    self.__marks = marks
  def display(self):
    print(f"Student name: {self.student_name}")
    print(f"Marks: {self.__marks}")

SG = StudentGrades("Ali", 80)
SG.display()
# SG.marks = 50     # Marks are not accessible and hence not changeable
SG.addMarks(50)
SG.display()
# Out:
# Student name: Ali
# Marks: 80
# Student name: Ali
# Marks: 50
